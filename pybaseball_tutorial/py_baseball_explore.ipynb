# %%
from pybaseball import statcast
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.patches import Ellipse

# %%
"""Finding Tanner Houck's stats"""
from pybaseball import playerid_lookup
from pybaseball import statcast_pitcher

playerid_lookup('houck', 'tanner')
# Out:
# Gathering player lookup table. This may take a moment.
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0     houck     tanner     656557  houct001  houckta01          19879
#
#    mlb_played_first  mlb_played_last
# 0            2020.0           2021.0

# %%
"""His MLBAM ID is 656557 so we can use that as the player_id argument"""
houck_stats = statcast_pitcher('2021-05-10', '2021-11-01', 656557)
houck_stats.head(2)
# Out:
# Gathering Player Data
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2021-10-22           95.6          -2.61           5.48
# 1         SL  2021-10-22           85.1          -2.82           5.76
#
#      player_name  batter  pitcher  events    description  ...  fld_score  \
# 0  Houck, Tanner  670541   656557  single  hit_into_play  ...          0
# 1  Houck, Tanner  670541   656557     NaN           foul  ...          0
#
#    post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 0                0                2               2               0
# 1                0                2               2               0
#
#   if_fielding_alignment of_fielding_alignment spin_axis delta_home_win_exp  \
# 0         Infield shift             Strategic     251.0              0.008
# 1         Infield shift             Strategic      52.0              0.000
#
#   delta_run_exp
# 0         0.566
# 1        -0.086
#
# ...

# %%
"""Finding Pitching stats"""
from pybaseball import pitching_stats
data = pitching_stats(2021, 2021)
data.head(5)
# Out:
#      IDfg  Season            Name   Team  Age   W   L  WAR   ERA   G  ...  \
# 0   19361    2021   Corbin Burnes    MIL   26  11   5  7.5  2.43  28  ...
# 4   10310    2021    Zack Wheeler    PHI   31  14  10  7.3  2.78  32  ...
# 24   9132    2021  Nathan Eovaldi    BOS   31  11   9  5.6  3.75  32  ...
# 2   19374    2021  Walker Buehler    LAD   26  16   4  5.5  2.47  33  ...
# 1    3137    2021    Max Scherzer  - - -   36  15   4  5.4  2.46  30  ...
#
#       LA  Barrels  Barrel%  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  \
# 0    8.4       12    0.031  114.2      117     0.305     383  0.172  0.338
# 4    8.4       25    0.046  118.6      156     0.285     548  0.156  0.280
# 24  12.8       33    0.063  115.6      191     0.362     527  0.173  0.299
# 2   11.1       37    0.068  114.4      201     0.369     545  0.181  0.296
# 1   19.3       33    0.080  113.3      141     0.343     411  0.157  0.316
#
#     xERA
# 0   2.00
# 4   2.79
# 24  3.37
# 2   3.10
# 1   2.90
#
# ...
