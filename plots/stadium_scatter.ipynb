# %%
import pybaseball as pb
from pybaseball import statcast, spraychart, get_splits
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
fenway = pb.plot_stadium('red_sox')

# %%
pb.playerid_lookup('Schwarber', 'Kyle' )
# Out:
#    name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0  schwarber       kyle     656941  schwk001  schwaky01          16478
#
#    mlb_played_first  mlb_played_last
# 0            2015.0           2021.0

# %%
data = pb.statcast_batter('2021-04-01', '2021-11-04',656941)
subdata = data[data['home_team'] == 'BOS']
subdata
# Out:
#     pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 18          SI  2021-10-20           95.7           0.78           5.90
# 19          SI  2021-10-20           94.7           0.83           5.90
# 20          CU  2021-10-20           78.3           0.80           5.73
# 21          SI  2021-10-20           95.2           0.82           5.86
# 22          SI  2021-10-20           94.7           0.89           5.93
# ..         ...         ...            ...            ...            ...
# 951       None  2021-08-13            NaN            NaN            NaN
# 952       None  2021-08-13            NaN            NaN            NaN
# 953       None  2021-08-13            NaN            NaN            NaN
# 954       None  2021-08-13            NaN            NaN            NaN
# 955       None  2021-08-13            NaN            NaN            NaN
#
#          player_name  batter  pitcher     events      description  ...  \
# ...

# %%
pb.spraychart(subdata, 'red_sox', title= 'Kyle Scwarber: April - November 2021')
# Out:
# /opt/anaconda3/envs/baseball_analytics_env/lib/python3.9/site-packages/pybaseball/plotting.py:114: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sub_data = sub_data[sub_data['events'].notna()][sub_data['hc_x'].notna()][sub_data['hc_y'].notna()]
# <Axes:title={'center':'Kyle Scwarber: April - November 2021'}>

# %% [markdown]
# ### Testing how a player would do if they played at Fenway

# %%
pb.playerid_lookup('Story', 'Trevor' )
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0     story     trevor     596115  stort001  storytr01          12564
#
#    mlb_played_first  mlb_played_last
# 0            2016.0           2021.0

# %%
data = pb.statcast_batter('2021-04-01', '2021-11-04',596115)

# %%
pb.spraychart(data, 'red_sox', title= 'Trevor Story: April - November 2021')
# Out:
# <Axes:title={'center':'Trevor Story: April - November 2021'}>
